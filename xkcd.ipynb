# %% [markdown]
# <a href="https://colab.research.google.com/github/noallynoclan/colab/blob/master/xkcd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

style.use('fivethirtyeight')
plt.xkcd()

# %%
size = 32
y = np.random.random(size).cumsum()
x = np.linspace(0, 10, size) 
z = np.exp(x) / 1000
fig, ax = plt.subplots(1, 1, figsize=(16, 9))

ax = plt.bar(x, z, width=x[1]-x[0]);
ax = plt.plot(x, z, c='r');
